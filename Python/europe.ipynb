# %% [markdown]
# #### European Countries
# Use set operations to determine which European countries are not in the European Union. Use the Country column.

# %% [markdown]
# - Checking the subset of countries in Europe

# %%
# Check to confirm that the EU countries are a subset of countries in Europe
import pandas as pd

#Load Europe and EU through pandas
europe_df = pd.read_excel('Europe_and_EU.xlsx',sheet_name='Europe')
eu_df=pd.read_excel('Europe_and_EU.xlsx',sheet_name='EU')

# %%
#cleaning country column in Europe_df
cleaned_europe=[]
for country in europe_df['Country']:
    country=country.strip()
    country=' '.join(country.split())
    country=country.title()
    cleaned_europe.append(country)
europe_df['Country']=cleaned_europe

# %%
#cleaning country column in Eu_df
cleaned_eu=[]
for country in eu_df['Country']:
    country=country.strip() # removes leading spaces
    country=' '.join(country.split()) # removes extra spaces between words* how to keep words like uk
    country=country.title() # capitalizes each word
    cleaned_eu.append(country)
eu_df['Country']=cleaned_eu

# %%
europe_df.head(10) #previewing data in the Europe sheet
# Out:
#    Rank         Country  Population  % of population  \
# 0   1.0          Russia   143964709            17.15
# 1   2.0        Germany     82521653             9.80
# 2   3.0         Turkey     80810000             9.60
# 3   4.0          France    65233271             7.76
# 4   5.0  United Kingdom    65110276             7.75
# 5   6.0          Italy     59320118             7.21
# 6   7.0          Spain     46397452             5.53
# 7   8.0         Ukraine    42895704             5.10
# 8   9.0         Poland     38104832             4.58
# 9  10.0        Romania     19622000             2.36
#
#    Average relative annual growth (%)  Average absolute annual growth  \
# 0                                0.19                          294285
# 1                                1.20                          600000
# 2                                1.34                         1035000
# 3                                0.39                          261022
# 4                                0.75                          484000
# 5                                0.49                          298000
# 6                               -0.06                          -28000
# 7                               -0.32                         -136000
# 8                                0.05                           20000
# 9                               -0.41                          -81000
#
#   Estimated doubling time (Years)  Official figure (where available)  \
# 0                             368                          146839993
# 1                              90                           82800000
# 2                              52                           77695904
# 3                             177                           66991000
# 4                              92                           66573504
# 5                             141                           60788845
# 6                              -                            46449565
# 7                              -                            42726067
# 8                            1334                           38484000
# 9                              -                            19942642
#
#    Date of last figure Regional grouping                     Source
# 0  2017-01-01 00:00:00             EAEU                         [1]
# 1  2016-12-31 00:00:00               EU           Official estimate
# 2  2016-12-31 00:00:00               NaN                        [2]
# 3  2017-03-01 00:00:00               EU                         [3]
# 4  2016-12-30 00:00:00               EU           Official estimate
# 5  2017-01-01 00:00:00               EU   Monthly official estimate
# 6  2015-01-01 00:00:00               EU           Official estimate
# 7  2015-03-01 00:00:00               NaN  Monthly official estimate
# 8  2014-12-31 00:00:00               EU           Official estimate
# 9  2014-01-01 00:00:00               EU           Official estimate

# %%
eu_df.head(10) #previewing data in the EU sheet.
# Out:
#    Rank         Country  2017 population  % of pop.  \
# 0     1         Germany         82800000      16.18
# 1     2          France         67210459      13.10
# 2     3  United Kingdom         65808573      12.86
# 3     4           Italy         60589445      11.84
# 4     5           Spain         46528966       9.09
# 5     6          Poland         37972964       7.42
# 6     7         Romania         19638309       3.84
# 7     8     Netherlands         17081507       3.34
# 8     9         Belgium         11365834       2.22
# 9    10          Greece         10757293       2.10
#
#    Average relative annual growth  Average absolute annual growth  \
# 0                            0.76                          628876
# 1                            0.40                          265557
# 2                            0.65                          428793
# 3                           -0.13                          -76001
# 4                            0.19                           89037
# 5                            0.02                            5756
# 6                           -0.62                         -121252
# 7                            0.60                          103004
# 8                            0.48                           54982
# 9                           -0.25                          -26390
#
#    Official figure Date of last figure                     Source
# 0         82576900          2017-03-31          Official estimate
# 1         67174000          2018-01-01  Monthly official estimate
# 2         65648100          2017-06-30          Official estimate
# 3         60494000          2018-01-01  Monthly official estimate
# 4         46549045          2017-07-01          Official estimate
# 5         38426000          2017-07-31          Official estimate
# 6         19638309          2017-01-01          Official estimate
# 7         17184010          2017-12-31  Monthly official estimate
# 8         11399335          2017-12-01  Monthly official estimate
# 9         10768193          2017-01-01          Official estimate

# %%
#Check to confirm that the EU countries are a subset of countries in Europe
#Convert to sets
europe_set=set(europe_df['Country'])
eu_set=set(eu_df['Country'])

# %%
#check if eu is a subset of europe.
is_subset = eu_set.issubset(europe_set)
print("Are all EU countries in the Europe list?:", is_subset)
# Out:
# Are all EU countries in the Europe list?: False

# %%
#show which EU countries are missing from Europe list
missing = eu_set - europe_set
print("EU countries not found in Europe list:", missing) #display result
# Out:
# EU countries not found in Europe list: {'Belgium', 'Lithuania', 'Slovakia', 'Czech Republic', 'Ireland', 'Poland', 'Bulgaria', 'Spain', 'Netherlands', 'Sweden', 'Germany', 'Estonia', 'Hungary', 'Latvia', 'Romania', 'Malta', 'Italy', 'Denmark', 'Portugal', 'Greece', 'Croatia', 'Austria', 'Finland', 'Cyprus', 'Luxembourg', 'Slovenia'}

# %%
#find countries in Europe but not in EU
europe_set = set(europe_df['Country']) #Convert to sets
eu_set = set(eu_df['Country'])

# %%
#subtract EU from Europe
non_eu_countries = europe_set - eu_set
print("Countries in Europe but not in the EU:", non_eu_countries)# non EU countries.
# Out:
# Countries in Europe but not in the EU: {' Montenegro ', ' Austria ', ' Serbia ', ' Liechtenstein ', ' Lithuania ', ' Andorra ', ' Faroe Islands (Denmark) ', ' Gibraltar (UK)', ' Portugal ', ' Russia', '  Switzerland ', ' Azerbaijan ', ' Malta ', ' Guernsey (UK) ', ' Belarus ', ' Slovenia ', ' Hungary ', ' Latvia ', ' Sweden ', ' Spain ', ' Macedonia ', ' Luxembourg ', ' Finland ', ' Romania ', ' Jersey (UK) ', ' Armenia ', ' Ukraine', ' Belgium ', ' San Marino ', ' Åland Islands (Finland) ', ' Ireland ', ' Albania ', ' Slovakia ', ' Georgia ', ' Isle of Man (UK) ', ' Poland ', ' Kosovo ', ' Italy ', ' Croatia ', ' Estonia ', ' Netherlands ', ' Iceland ', ' Monaco ', '  Vatican City ', ' Svalbard (Norway) ', ' Denmark ', ' Bosnia and Herzegovina ', ' Germany ', ' Turkey ', ' Norway ', ' Bulgaria ', ' Moldova ', ' Greece ', ' Cyprus ', ' Czech Republic '}

# %%
print("Number of countries in Europe but not in the EU:", len(non_eu_countries))
non_eu_countries = europe_set - eu_set
print(sorted(non_eu_countries))
# Out:
# Number of countries in Europe but not in the EU: 55
# ['  Switzerland ', '  Vatican City ', ' Albania ', ' Andorra ', ' Armenia ', ' Austria ', ' Azerbaijan ', ' Belarus ', ' Belgium ', ' Bosnia and Herzegovina ', ' Bulgaria ', ' Croatia ', ' Cyprus ', ' Czech Republic ', ' Denmark ', ' Estonia ', ' Faroe Islands (Denmark) ', ' Finland ', ' Georgia ', ' Germany ', ' Gibraltar (UK)', ' Greece ', ' Guernsey (UK) ', ' Hungary ', ' Iceland ', ' Ireland ', ' Isle of Man (UK) ', ' Italy ', ' Jersey (UK) ', ' Kosovo ', ' Latvia ', ' Liechtenstein ', ' Lithuania ', ' Luxembourg ', ' Macedonia ', ' Malta ', ' Moldova ', ' Monaco ', ' Montenegro ', ' Netherlands ', ' Norway ', ' Poland ', ' Portugal ', ' Romania ', ' Russia', ' San Marino ', ' Serbia ', ' Slovakia ', ' Slovenia ', ' Spain ', ' Svalbard (Norway) ', ' Sweden ', ' Turkey ', ' Ukraine', ' Åland Islands (Finland) ']

# %%
import pandas as pd
non_eu_df = pd.DataFrame(sorted(non_eu_countries), columns=['Country']) # convert set to a data frame
print(non_eu_df)
# Out:
#                       Country
# 0                Switzerland
# 1               Vatican City
# 2                    Albania
# 3                    Andorra
# 4                    Armenia
# 5                    Austria
# 6                 Azerbaijan
# 7                    Belarus
# 8                    Belgium
# 9     Bosnia and Herzegovina
# 10                  Bulgaria
# 11                   Croatia
# 12                    Cyprus
# 13            Czech Republic
# 14                   Denmark
# 15                   Estonia
# 16   Faroe Islands (Denmark)
# 17                   Finland
# 18                   Georgia
# 19                   Germany
# 20             Gibraltar (UK)
# 21                    Greece
# 22             Guernsey (UK)
# 23                   Hungary
# 24                   Iceland
# 25                   Ireland
# 26          Isle of Man (UK)
# 27                     Italy
# 28               Jersey (UK)
# 29                    Kosovo
# 30                    Latvia
# 31             Liechtenstein
# 32                 Lithuania
# 33                Luxembourg
# 34                 Macedonia
# 35                     Malta
# 36                   Moldova
# 37                    Monaco
# 38                Montenegro
# 39               Netherlands
# 40                    Norway
# 41                    Poland
# 42                  Portugal
# 43                   Romania
# 44                     Russia
# 45                San Marino
# 46                    Serbia
# 47                  Slovakia
# 48                  Slovenia
# 49                     Spain
# 50         Svalbard (Norway)
# 51                    Sweden
# 52                    Turkey
# 53                    Ukraine
# 54   Åland Islands (Finland)

# %%
# visuals using a venn diagram
from matplotlib import pyplot as plt
from matplotlib_venn import venn2

# %%
venn2([europe_set, eu_set], set_labels=('Europe', 'EU'))
plt.title("Europe vs EU Countries")
plt.show()
